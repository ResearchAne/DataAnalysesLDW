# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import math
import cv2
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline

# %%
#reading in an image
title= "Bare_road"
img = mpimg.imread('testImages/whiteYellow2.jpg')

#printing out some stats and plotting
print('This image is:', type(img), 'with dimensions:', img.shape)

plt.imshow(img)  # if you wanted to show a single color channel image called 'gray', for example, call as plt.imshow(gray, cmap='gray')

plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'.jpg')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (1088, 2288, 3)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap='gray')
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_gray'+'.jpg')

# %%
hls = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
plt.imshow(hls)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_hls'+'.jpg')

# %%
H = hls[:,:,0]
L = hls[:,:,1]
S = hls[:,:,2]
plt.imshow(H)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_hls_h'+'.jpg')

# %%
plt.imshow(L)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_hls_L'+'.jpg')

# %%
plt.imshow(S)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_hls_s'+'.jpg')

# %%
R = img[:,:,0]
G = img[:,:,1]
B = img[:,:,2]
plt.imshow(R)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_R'+'.jpg')

# %%
plt.imshow(B)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_B'+'.jpg')

# %%
plt.imshow(G)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_G'+'.jpg')

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
plt.imshow(hsv)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_hsv'+'.jpg')

# %%
H2 = hsv[:,:,0]
S2 = hsv[:,:,1]
V = hsv[:,:,2]
plt.imshow(H2)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_hsv_h'+'.jpg')

# %%
plt.imshow(S2)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_hsv_s'+'.jpg')

# %%
plt.imshow(V)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_hsv_v'+'.jpg')

# %%
yuv = cv2.cvtColor(img, cv2.COLOR_RGB2YUV)
plt.imshow(yuv)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_yuv'+'.jpg')

# %%
Y = yuv[:,:,0]
U = yuv[:,:,1]
V2 = yuv[:,:,2]
plt.imshow(Y)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_yuv_y'+'.jpg')

# %%
plt.imshow(U)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_yuv_u'+'.jpg')

# %%
plt.imshow(V2)
plt.savefig('C:/Users/aneds/Pictures/LD/'+title+'/'+title+'_yuv_v'+'.jpg')
